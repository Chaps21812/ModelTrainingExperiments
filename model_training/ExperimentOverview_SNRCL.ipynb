# %%
from evaluation.dataset_studies import Single_Dataset_Study, Multi_Dataset_Study

# %%
#Early Stopping
SE1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_Sim1Real_2025-08-25_10:58"
SE2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_Sim2Real_2025-08-25_10:58"
SE5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_Sim5Real_2025-08-26_05:21"
RE1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_CL1Real_2025-08-25_10:57"
RE2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_CL2Real_2025-08-25_10:57"
RE5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_CL5Real_2025-08-25_10:58"

#No early stopping
S1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_Sim1Real_2025-08-28_06:12"
S2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_Sim2Real_2025-08-28_06:13"
S5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_Sim5Real_2025-08-28_06:19"
R1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_CL1Real_2025-08-28_06:12"
R2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_CL2Real_2025-08-28_06:12"
R5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_CL5Real_2025-08-28_06:12"

color_legend=["1 Step", "2 Step", "5 Step", "1 Step", "2 Step", "5 Step"]
shape_legend=["Satsim", "Satsim", "Satsim", "Real", "Real", "Real"]
experiments = [S1, S2, S5, R1, R2, R5] 

Real_color_legend=["1 Step", "2 Step", "5 Step"]
Real_shape_legend=[ "Real", "Real", "Real"]
Real_experiments = [R1, R2, R5] 

Sim_color_legend=["1 Step", "2 Step", "5 Step"]
Sim_shape_legend=["Satsim", "Satsim", "Satsim"]
Sim_experiments = [S1, S2, S5]

# %%
save_path = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/CL_Plots_WACV'
real_only = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/CL_Plots_WACV/real_only"
sim_only = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/CL_Plots_WACV/sim_only"
multi_study = Multi_Dataset_Study(experiments, color_legend, second_characteristic=shape_legend,save_path=save_path, second_char_type="shape", color_gradient=None)
multi_study.plot_combined_PR_Curves(threshold_fit=4, split_legend=False, shape_size=4)

real_data_only = Multi_Dataset_Study(Real_experiments, Real_color_legend, second_characteristic=Real_shape_legend,save_path=real_only, second_char_type="shape", color_gradient=None)
real_data_only.plot_combined_per_attribute_PR("local_snr", curve="precision",log_x=True)
real_data_only.plot_combined_per_attribute_PR("local_snr", curve="recall",log_x=True)
real_data_only.plot_combined_per_attribute_PR("local_snr", curve="f1",log_x=True)

sim_data_only = Multi_Dataset_Study(Sim_experiments, Sim_color_legend, second_characteristic=Sim_shape_legend,save_path=sim_only, second_char_type="shape", color_gradient=None)
sim_data_only.plot_combined_per_attribute_PR("snr", curve="precision",log_x=True)
sim_data_only.plot_combined_per_attribute_PR("snr", curve="recall",log_x=True)
sim_data_only.plot_combined_per_attribute_PR("snr", curve="f1",log_x=True)

# %%
save_path = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/CL_Plots_WACV'
real_only = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/CL_Plots_WACV/real_only"
sim_only = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/CL_Plots_WACV/sim_only"
multi_study = Multi_Dataset_Study(experiments, color_legend, second_characteristic=shape_legend,save_path=save_path, second_char_type="shape", color_gradient=None)
multi_study.plot_combined_PR_Curves(threshold_fit=4, split_legend=False, shape_size=4)

real_data_only = Multi_Dataset_Study(Real_experiments, Real_color_legend, second_characteristic=Real_shape_legend,save_path=real_only, second_char_type="shape", color_gradient=None)
real_data_only.plot_combined_per_attribute_PR("local_snr", curve="precision",log_x=True)
real_data_only.plot_combined_per_attribute_PR("local_snr", curve="recall",log_x=True)
real_data_only.plot_combined_per_attribute_PR("local_snr", curve="f1",log_x=True)

sim_data_only = Multi_Dataset_Study(Sim_experiments, Sim_color_legend, second_characteristic=Sim_shape_legend,save_path=sim_only, second_char_type="shape", color_gradient=None)
sim_data_only.plot_combined_per_attribute_PR("snr", curve="precision",log_x=True)
sim_data_only.plot_combined_per_attribute_PR("snr", curve="recall",log_x=True)
sim_data_only.plot_combined_per_attribute_PR("snr", curve="f1",log_x=True)
