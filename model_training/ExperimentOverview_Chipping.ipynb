# %%
from evaluation.dataset_studies import Single_Dataset_Study, Multi_Dataset_Study

# %%
A1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-10_2025-08-25_11:31"
A2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-20_2025-08-25_11:32"
A3 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-30_2025-08-25_11:32"
A4 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-R_2025-08-25_11:33"
A5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-NoChip_2025-08-26_04:34"
A6 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L2-R_2025-08-26_04:29"
A7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L2-NoChip_2025-08-26_04:28"
A8 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_R4-R_2025-08-25_11:57"
A9 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_R4-NoChip_2025-08-25_11:50"

color_legend=["10% Overlap", "20% Overlap", "30% Overlap", "R Overlap", "No Chipping", "R Overlap", "No Chipping", "R Overlap", "No Chipping"]
shape_legend=["Telescope A", "Telescope A", "Telescope A", "Telescope A", "Telescope A", "Telescope B", "Telescope B", "Telescope C", "Telescope C"]

experiments = [A1, A2, A3, A4, A5, A6, A7, A8, A9]

# %%
A1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-10_2025-08-25_11:31"
A2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-20_2025-08-25_11:32"
A3 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-30_2025-08-25_11:32"
A4 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-R_2025-08-25_11:33"
A5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-NoChip_2025-08-26_04:34"
A6 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L2-R_2025-08-26_04:29"
A7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L2-NoChip_2025-08-26_04:28"
A8 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_R4-R_2025-08-25_11:57"
A9 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_R4-NoChip_2025-08-25_11:50"

color_legend=["10% Overlap", "20% Overlap", "30% Overlap", "R Overlap", "No Chipping" ]
shape_legend=["Telescope A", "Telescope A", "Telescope A", "Telescope A", "Telescope A"]

experiments = [A1, A2, A3, A4, A5]

# %%
A1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-10_2025-08-25_11:31"
A2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-20_2025-08-25_11:32"
A3 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-30_2025-08-25_11:32"
A4 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-R_2025-08-25_11:33"
A5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L1-NoChip_2025-08-26_04:34"
A6 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L2-R_2025-08-26_04:29"
A7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L2-NoChip_2025-08-26_04:28"
A8 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_R4-R_2025-08-25_11:57"
A9 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_R4-NoChip_2025-08-25_11:50"

color_legend=[ "R Overlap", "No Chipping", "R Overlap", "No Chipping", "R Overlap", "No Chipping"]
shape_legend=["Telescope A", "Telescope A", "Telescope B", "Telescope B", "Telescope C", "Telescope C"]

experiments = [ A4, A5, A6, A7, A8, A9]

# %%
for e in experiments:
    dataset_study:Single_Dataset_Study = Single_Dataset_Study.load(e)
    dataset_study.plot_PR_Curves()

# %%
save_path = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/SPIEFutureSensingImageChipping/EarlyStopping'
# multi_study = Multi_Dataset_Study(experiments, color_legend, second_characteristic=shape_legend,save_path=save_path, second_char_type="line", color_gradient=("#3DB5D7", "#FB0202FF") )
multi_study = Multi_Dataset_Study(experiments, color_legend, second_characteristic=shape_legend,save_path=save_path, second_char_type="shape", color_gradient=None)
multi_study.plot_combined_PR_Curves(threshold_fit=4, split_legend=True, shape_size=4)
multi_study.print_f1star(4)
# Out:
# Evaluation_L1-10_2025-08-25_11:31, F1* = 0.18, P* = 0.11, R* = 0.58
# Evaluation_L1-20_2025-08-25_11:32, F1* = 0.15, P* = 0.09, R* = 0.49
# Evaluation_L1-30_2025-08-25_11:32, F1* = 0.57, P* = 0.47, R* = 0.72
# Evaluation_L1-R_2025-08-25_11:33, F1* = 0.28, P* = 0.18, R* = 0.65
# Evaluation_L1-NoChip_2025-08-26_04:34, F1* = 0.13, P* = 0.08, R* = 0.46
# Evaluation_L2-R_2025-08-26_04:29, F1* = 0.30, P* = 0.19, R* = 0.66
# Evaluation_L2-NoChip_2025-08-26_04:28, F1* = 0.01, P* = 0.00, R* = 0.48
# Evaluation_R4-R_2025-08-25_11:57, F1* = 0.13, P* = 0.08, R* = 0.47
# Evaluation_R4-NoChip_2025-08-25_11:50, F1* = 0.06, P* = 0.04, R* = 0.16
#
# Evaluation_L1-10_2025-08-25_11:31&4&0.18&0.11&0.58\\
# Evaluation_L1-20_2025-08-25_11:32&4&0.15&0.09&0.49\\
# Evaluation_L1-30_2025-08-25_11:32&4&0.57&0.47&0.72\\
# Evaluation_L1-R_2025-08-25_11:33&4&0.28&0.18&0.65\\
# Evaluation_L1-NoChip_2025-08-26_04:34&4&0.13&0.08&0.46\\
# Evaluation_L2-R_2025-08-26_04:29&4&0.30&0.19&0.66\\
# ...
