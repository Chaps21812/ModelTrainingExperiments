# %%
from astropy.io import fits
import json
import os
from evaluation.dataset_studies import Dataset_study, CompiledExperiments, Single_Dataset_Study

dataset_study= "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_L2_E122_2025-11-17_07:08"
experiments = Single_Dataset_Study.load(dataset_study)
experiments.plot_PR_Curves()
experiments.plot_per_attribute_PR("local_snr", 20, log_y=False)
experiments.plot_per_attribute_PR("x_center", 20)
experiments.plot_per_attribute_PR("y_center", 20)

# %% [markdown]
# # Single Experiment plots

# %%
pickle_pathA = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_LMNT01-2024_2025-10-09_06:20"
pickle_pathB = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_RME01-2024_2025-10-09_06:27"
pickle_pathC = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_RME05-2025_2025-10-09_06:35"
experiments:Single_Dataset_Study = Single_Dataset_Study.load('/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Testing_2025-10-13_07:59')
experiments.plot_PR_Curves()

# %%
pickle_pathA = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_LMNT01-2024_2025-10-09_06:20"
pickle_pathB = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_RME01-2024_2025-10-09_06:27"
pickle_pathC = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_RME05-2025_2025-10-09_06:35"
pickle_pathD = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Testing_2025-10-10_09:27"

DemoA = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Demo-R4-Small_2025-10-13_11:32"
DemoB = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Demo-L1-Small_2025-10-13_11:48"
DemoC = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Demo-L2-Small_2025-10-13_11:32"
DemoD = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Demo-L1-2024-Large_2025-10-13_11:29"
DemoE = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Demo-R1-2025-Large_2025-10-13_11:30"
DemoF = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Demo-R4-2025-Large_2025-10-13_11:30"
DemoG = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Demo-L1-large_OOD-2025-10-13_12:25"
DemoH = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Recentroid-2025-10-14_05:10_0PixelSpread"
DemoI = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Recentroid-2025-10-14_05:28_1PixelSpread"
DemoJ = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Recentroid-2025-10-14_03:30_2Pixel_Spread"
DemoK = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Recentroid-2025-10-14_05:17_4PixelSpread"
DemoL = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Recentroid-2025-10-14_03:59_8PixelSpread"
# 

RecentA = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Recentroid-L1-2024L-2025-10-14_05:43"
RecentB = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Recentroid-R4-2025-2025-10-14_05:43"
RecentC = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Recentroid-R1-2025-2025-10-14_05:42"
RecentD = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Recentroid-L1Small-2025-10-14_05:44"
RecentE = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Recentroid-L2Small-2025-10-14_05:44"
RecentF = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Recentroid-R4Small-2025-10-14_05:45"

# for path in [DemoA,DemoB,DemoC,DemoD,DemoE,DemoF,DemoG,DemoH,DemoI,DemoJ,DemoK,DemoL]:
for path in [RecentA,RecentB,RecentC,RecentD,RecentE,RecentF]:
    experiments:Single_Dataset_Study = Single_Dataset_Study.load(path)
    experiments.plot_PR_Curves(plot_format="png",best_precision=0.99)

# %% [markdown]
# # Production Work

# %%
A1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Prod_Auto_Eval_Production-ABQ01-2025-Annotations_weights_E46.pt_Calsat_Final-ABQ01-2025_2025-11-19_15:51"
A2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Prod_Auto_Eval_Production-All_Data_weights_E15.pt_Calsat_Final-ABQ01-2025_2025-11-19_17:41"
A3 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Prod_Auto_Eval_Production-LMNT-Holdout_weights_E15.pt_Calsat_Final-ABQ01-2025_2025-11-20_05:48"
A4 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Prod_Auto_Eval_Production-SatNet1.4_weights_E57.pt_Calsat_Final-ABQ01-2025_2025-11-19_16:45"
A5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Prod_Auto_Eval_Production-100kLimited_weights_E10.pt_Calsat_Final-ABQ01-2025_2025-11-20_06:45"


[A1 ,A2, A3, A4, A5]
for exp in [A1 ,A2, A3, A4, A5]:
    experiments = Single_Dataset_Study.load(exp)
    experiments.plot_PR_Curves()
    experiments.plot_per_attribute_PR("local_snr", 20, log_y=False)
    experiments.plot_per_attribute_PR("x_center", 20)
    experiments.plot_per_attribute_PR("y_center", 20)

# %% [markdown]
# ## Plot Precision Recall Curves

# %%
experiments.plot_PR_Curves()

# %% [markdown]
# ## Plot Precision Recall F1 as a function of Attribute

# %%
experiments.plot_per_attribute_PR("SNRs", 20)

# %% [markdown]
# ## Plot All Metrics

# %%
experiments.plot_all_metrics()

# %% [markdown]
# # Multi Experiment Plots

# %% [markdown]
# ## Set Directories for plots

# %%
directories = [
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R1_on_TA_Data2025-08-06_15:17",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R1_on_TA_Data2025-08-06_15:26", 
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R1_on_TA_Data2025-08-06_15:31", 
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R2_on_TA_Data2025-08-06_15:19",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R2_on_TA_Data2025-08-06_15:26", 
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R2_on_TA_Data2025-08-06_15:31", 
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R5_on_TA_Data2025-08-06_15:19",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R5_on_TA_Data2025-08-06_15:26",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R5_on_TA_Data2025-08-06_15:31",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/S1R1_on_TA_Data2025-08-06_15:20",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/S1R1_on_TA_Data2025-08-06_15:26",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/S1R1_on_TA_Data2025-08-06_15:31",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/S2R2_on_TA_Data2025-08-06_15:20",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/S2R2_on_TA_Data2025-08-06_15:26",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/S2R2_on_TA_Data2025-08-06_15:31",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/S5R5_on_TA_Data2025-08-06_15:20",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/S5R5_on_TA_Data2025-08-06_15:26",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/S5R5_on_TA_Data2025-08-06_15:32"
    ]

shape_labels = [
                "Telescope A", 
                "Telescope B",
                "Telescope C",
                "Telescope A", 
                "Telescope B",
                "Telescope C",
                "Telescope A", 
                "Telescope B",
                "Telescope C",
                "Telescope A", 
                "Telescope B",
                "Telescope C",
                "Telescope A", 
                "Telescope B",
                "Telescope C",
                "Telescope A", 
                "Telescope B",
                "Telescope C",
                ]
color_labels = [
                "Real 1 Steps",
                "Real 1 Steps",
                "Real 1 Steps", 
                "Real 2 Steps",
                "Real 2 Steps",
                "Real 2 Steps", 
                "Real 5 Steps",
                "Real 5 Steps",
                "Real 5 Steps", 
                "Sim + Real 1 Steps",
                "Sim + Real 1 Steps",
                "Sim + Real 1 Steps", 
                "Sim + Real 2 Steps",
                "Sim + Real 2 Steps",
                "Sim + Real 2 Steps", 
                "Sim + Real 5 Steps",
                "Sim + Real 5 Steps",
                "Sim + Real 5 Steps", 
                ]
directories = [
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R1_on_TA_Data2025-08-08_06:03",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R2_on_TA_Data2025-08-08_06:04",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R5_on_TA_Data2025-08-08_06:07",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/S1R1_on_TA_Data2025-08-06_15:20",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/S2R2_on_TA_Data2025-08-06_15:20",
    "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/S5R5_on_TA_Data2025-08-06_15:20",
    ]

shape_labels = [
                "Telescope A", 
                "Telescope A", 
                "Telescope A", 
                "Telescope A", 
                "Telescope A", 
                "Telescope A", 
                ]
color_labels = [
                "Real 1 Step CL",
                "Real 2 Step CL",
                "Real 5 Step CL",
                "Simulation and Real 1 Step CL",
                "Simulation and Real 4 Step CL",
                "Simulation and Real 10 Step CL",
                ]
save_path = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/JustinsPlots/IACCurriculumLearning"
experiments = CompiledExperiments(directories,color_labels,shape_labels, save_path, save_type="pdf")

# %% [markdown]
# ## Plot Combined PR Curves

# %%
experiments.plot_combined_PR_Curves()

# %% [markdown]
# ## Plot per SNR

# %%
experiments.plot_combined_per_attribute_PR("SNRs", log_x=True, curve="precision")

# %%
experiments.plot_combined_PR_Curves()

# %% [markdown]
# ## Plot Metrics over time

# %%
experiments.plot_metrics_over_time()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 experiments.plot_metrics_over_time()
#
# File ~/Repos/ModelTrainingExperiments/model_training/evaluation/dataset_studies.py:331, in CompiledExperiments.plot_metrics_over_time(self)
#     329 def plot_metrics_over_time(self):
#     330     for key in self.dataframes[0].columns:
# --> 331         self.plot_metric(key)
#
# File ~/Repos/ModelTrainingExperiments/model_training/evaluation/dataset_studies.py:355, in CompiledExperiments.plot_metric(self, metric)
#     353 except KeyError: continue
#     354 if metric != "date":
# --> 355     if df[metric].max() >1:
#     356         large_range=True
#     358 days_since_start = (df["date"]-df["date"].min()).dt.days
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %% [markdown]
# ## Print metric statistics

# %%
experiments.print_metric_avgs()
# Out:
# Model: Real 1 Step
# Dataset: Telescope A
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/RetinaNet/lib/python3.12/site-packages/pandas/core/nanops.py:1703, in _ensure_numeric(x)
#    1702 try:
# -> 1703     x = float(x)
#    1704 except (TypeError, ValueError):
#    1705     # e.g. "1+1j" or "foo"
#
# TypeError: float() argument must be a string or a real number, not 'list'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 experiments.print_metric_avgs()
#
# File ~/Repos/ModelTrainingExperiments/model_training/evaluation/dataset_studies.py:390, in CompiledExperiments.print_metric_avgs(self)
#     388 print(f"Model: {self.color_legend[index]}")
#     389 print(f"Dataset: {self.shape_legend[index]}")
# ...

# %% [markdown]
# ## Plot Combined Metrics Plots

# %%
experiments.combine_metric_plots(["F1", "Precision","Recall"])
# Out:
# /home/davidchaparro/Repos/ModelTrainingExperiments/model_training/evaluation/dataset_studies.py:330: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   plt.ylim(bottom=min_value, top=1)
