# %%
from evaluation.dataset_studies import Single_Dataset_Study, Multi_Dataset_Study

# %%
CL1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/SR1_on_TA_Data2025-08-10_20:01"
CL2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/SR1_on_TB_Data2025-08-10_20:01"
CL3 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/SR1_on_TC_Data2025-08-10_20:01"
CL4 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/SR2_on_TA_Data2025-08-10_20:09"
CL5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/SR2_on_TC_Data2025-08-10_20:08"
CL6 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/SR5_on_TA_Data2025-08-10_20:03"
CL7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/SR5_on_TB_Data2025-08-10_20:03"
CL8 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/SR5_on_TC_Data2025-08-10_20:04"


save_path = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/CL_Plots_WACV/Domain_transfer'
color_legend=["Telescope A", "Telescope B", "Telescope C", "Telescope A", "Telescope C", "Telescope A", "Telescope B", "Telescope C"]
shape_legend=["1 Step", "1 Step", "1 Step", "2 Step", "2 Step", "5 Step", "5 Step", "5 Step"]
experiments = [CL1,CL2,CL3,CL4,CL5,CL6,CL7,CL8]

# %%
CL1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R1_on_TA_Data2025-08-08_06:03"
CL2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R1_on_TB_Data2025-08-08_06:03"
CL3 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R1_on_TC_Data2025-08-08_06:03"
CL4 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R2_on_TA_Data2025-08-08_06:04"
CL5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R2_on_TB_Data2025-08-08_06:04"
CL6 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R5_on_TA_Data2025-08-08_06:07"
CL7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R5_on_TB_Data2025-08-08_06:07"
CL8 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R5_on_TC_Data2025-08-08_06:07"


save_path = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/CL_Plots_WACV/Domain_transfer_31epoch'
color_legend=["Telescope A", "Telescope B", "Telescope C", "Telescope A", "Telescope B", "Telescope A", "Telescope B", "Telescope C"]
shape_legend=["1 Step", "1 Step", "1 Step", "2 Step", "2 Step", "5 Step", "5 Step", "5 Step"]
experiments = [CL1,CL2,CL3,CL4,CL5,CL6,CL7,CL8]

# %%
CL1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R1_on_TA_Data2025-08-08_06:03"
CL2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R1_on_TB_Data2025-08-08_06:03"
CL3 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R1_on_TC_Data2025-08-08_06:03"
CL4 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R2_on_TA_Data2025-08-08_06:04"
CL5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R2_on_TB_Data2025-08-08_06:04"
CL6 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R5_on_TA_Data2025-08-08_06:07"
CL7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R5_on_TB_Data2025-08-08_06:07"
CL8 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/R5_on_TC_Data2025-08-08_06:07"


save_path = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/CL_Plots_WACV/Domain_transfer_31epoch'
color_legend=["Telescope A", "Telescope B", "Telescope C", "Telescope A", "Telescope B", "Telescope A", "Telescope B", "Telescope C"]
shape_legend=["1 Step", "1 Step", "1 Step", "2 Step", "2 Step", "5 Step", "5 Step", "5 Step"]
experiments = [CL1,CL2,CL3,CL4,CL5,CL6,CL7,CL8]

# %%
multi_study = Multi_Dataset_Study(experiments, color_legend, second_characteristic=shape_legend,save_path=save_path, second_char_type="shape", color_gradient=None)
multi_study.plot_combined_PR_Curves(threshold_fit=2, split_legend=False, shape_size=5)
