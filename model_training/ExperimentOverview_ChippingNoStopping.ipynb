# %%
from evaluation.dataset_studies import Single_Dataset_Study, Multi_Dataset_Study

# %%
#No Stop experiments done at epoch 75 
A1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-NoChip_2025-09-01_06:17" #6737
A2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-10_2025-08-26_04:53" #10058
A3 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-20_2025-08-26_04:53" #10322
A4 = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-30_2025-08-29_12:53' #26863
A5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-R_2025-08-26_04:53" #15369
A6 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-30Small_2025-08-29_12:52" #10000
A7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-SmallR_2025-09-01_06:17" #10000
A8 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=0.33_2025-09-11_06:10" #9018
A9 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=24_2025-09-11_06:10" #13669
A10 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=2_2025-09-15_04:58" #20936
A11 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=5_2025-09-12_04:50" #42690
A12 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-alpha=0.125_2025-09-12_04:52"



color_legend=["No Chipping", "10% Overlap", "20% Overlap","30% Overlap", "R Overlap", "Data Limited 30% Overlap", "Data Limited Random Overlap", "R=0.33", "R=1", "R=2", "R=5"]
shape_legend=["Telescope A", "Telescope A",  "Telescope A","Telescope A","Telescope A", "Telescope A","Telescope A","Telescope A","Telescope A", "Telescope A", "Telescope A"]
experiments = [A1,A2,A3,A4,A5,A6,A7,A8,A9,A10,A11]
dataset_sizes = [6737,10058,10322,26863,15369,10000,10000,9018,13669,20936,42690]

tfit=8

save_path = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/SPIEFutureSensingImageChipping/NoStopping'
multi_study = Multi_Dataset_Study(experiments, color_legend, second_characteristic=shape_legend,save_path=save_path, second_char_type="shape", color_gradient=None, dataset_sizes=dataset_sizes)
multi_study.plot_combined_PR_Curves(threshold_fit=tfit, split_legend=True, shape_size=5)
multi_study.print_f1star(tfit=tfit)
multi_study.calculate_scaling_law(tfit=8, tconf=0.5)
# Out:
# Evaluation_NoStop_L1-NoChip_2025-09-01_06:17, F1* = 0.57, P* = 0.46, R* = 0.75
# Evaluation_NoStop_L1-10_2025-08-26_04:53, F1* = 0.46, P* = 0.32, R* = 0.78
# Evaluation_NoStop_L1-20_2025-08-26_04:53, F1* = 0.67, P* = 0.57, R* = 0.80
# Evaluation_NoStop_L1-30_2025-08-29_12:53, F1* = 0.72, P* = 0.66, R* = 0.81
# Evaluation_NoStop_L1-R_2025-08-26_04:53, F1* = 0.68, P* = 0.58, R* = 0.81
# Evaluation_NoStop_L1-30Small_2025-08-29_12:52, F1* = 0.45, P* = 0.32, R* = 0.74
# Evaluation_NoStop_L1-SmallR_2025-09-01_06:17, F1* = 0.41, P* = 0.29, R* = 0.73
# Eval_L1-R=0.33_2025-09-11_06:10, F1* = 0.52, P* = 0.39, R* = 0.79
# Eval_L1-R=24_2025-09-11_06:10, F1* = 0.69, P* = 0.61, R* = 0.80
# Eval_L1-R=2_2025-09-15_04:58, F1* = 0.70, P* = 0.60, R* = 0.82
# Eval_L1-R=5_2025-09-12_04:50, F1* = 0.77, P* = 0.72, R* = 0.84
#
# Evaluation_NoStop_L1-NoChip_2025-09-01_06:17&8&0.57&0.46&0.75\\
# Evaluation_NoStop_L1-10_2025-08-26_04:53&8&0.46&0.32&0.78\\
# ...

# %%
#No Stop experiments done at epoch 75 
A1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-NoChip_2025-09-01_06:17" #6737
A2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-10_2025-08-26_04:53" #10058
A3 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-20_2025-08-26_04:53" #10322
A4 = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-30_2025-08-29_12:53' #26863
A5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-R_2025-08-26_04:53" #15369
A6 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-30Small_2025-08-29_12:52" #10000
A7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-SmallR_2025-09-01_06:17" #10000
A8 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=0.33_2025-09-11_06:10" #9018
A9 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=24_2025-09-11_06:10" #13669
A10 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=2_2025-09-15_04:58" #20936
A11 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=5_2025-09-12_04:50" #42690
A12 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-alpha=0.125_2025-09-12_04:52"



color_legend=["No Chipping", "10% Overlap", "20% Overlap","30% Overlap", "R Overlap", "Data Limited 30% Overlap", "Data Limited Random Overlap", "R=0.33", "R=1", "R=2", "R=5"]
shape_legend=["Telescope A", "Telescope A",  "Telescope A","Telescope A","Telescope A", "Telescope A","Telescope A","Telescope A","Telescope A", "Telescope A", "Telescope A"]
experiments = [A1,A2,A3,A4,A5,A6,A7,A8,A9,A10,A11]
dataset_sizes = [6737,10058,10322,26863,15369,10000,10000,9018,13669,20936,42690]

tfit=8

save_path = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/SPIEFutureSensingImageChipping/NoStopping'
multi_study = Multi_Dataset_Study(experiments, color_legend, second_characteristic=shape_legend,save_path=save_path, second_char_type="shape", color_gradient=None, dataset_sizes=dataset_sizes)
multi_study.plot_combined_PR_Curves(threshold_fit=tfit, split_legend=True, shape_size=5)
multi_study.print_f1star(tfit=tfit)
multi_study.calculate_scaling_law(tfit=8, tconf=0.5)
# Out:
# Evaluation_NoStop_L1-NoChip_2025-09-01_06:17, F1* = 0.57, P* = 0.46, R* = 0.75
# Evaluation_NoStop_L1-10_2025-08-26_04:53, F1* = 0.46, P* = 0.32, R* = 0.78
# Evaluation_NoStop_L1-20_2025-08-26_04:53, F1* = 0.67, P* = 0.57, R* = 0.80
# Evaluation_NoStop_L1-30_2025-08-29_12:53, F1* = 0.72, P* = 0.66, R* = 0.81
# Evaluation_NoStop_L1-R_2025-08-26_04:53, F1* = 0.68, P* = 0.58, R* = 0.81
# Evaluation_NoStop_L1-30Small_2025-08-29_12:52, F1* = 0.45, P* = 0.32, R* = 0.74
# Evaluation_NoStop_L1-SmallR_2025-09-01_06:17, F1* = 0.41, P* = 0.29, R* = 0.73
# Eval_L1-R=0.33_2025-09-11_06:10, F1* = 0.52, P* = 0.39, R* = 0.79
# Eval_L1-R=24_2025-09-11_06:10, F1* = 0.69, P* = 0.61, R* = 0.80
# Eval_L1-R=2_2025-09-15_04:58, F1* = 0.70, P* = 0.60, R* = 0.82
# Eval_L1-R=5_2025-09-12_04:50, F1* = 0.77, P* = 0.72, R* = 0.84
#
# Evaluation_NoStop_L1-NoChip_2025-09-01_06:17&8&0.57&0.46&0.75\\
# Evaluation_NoStop_L1-10_2025-08-26_04:53&8&0.46&0.32&0.78\\
# ...

# %%
#No Stop experiments done at epoch 75 
A1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-10_2025-08-26_04:53"
A2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-20_2025-08-26_04:53"
A3 = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-30_2025-08-29_12:53'
A5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-R_2025-08-26_04:53"
A7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-NoChip_2025-09-01_06:17"


color_legend=["No Chipping", "10% Overlap", "20% Overlap","30% Overlap","Random Overlap"]
shape_legend=["Telescope A", "Telescope A",  "Telescope A","Telescope A","Telescope A"]
# shape_legend=["Baseline", "Overlap",  "Overlap","Overlap","Overlap"]
experiments = [A7, A1, A2, A3, A5]

tfit=8

save_path = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/SPIEFutureSensingImageChipping/NoStopping/Nosmall'
multi_study = Multi_Dataset_Study(experiments, color_legend, second_characteristic=shape_legend,save_path=save_path, second_char_type="shape", color_gradient=None)
multi_study.plot_combined_PR_Curves(threshold_fit=tfit, split_legend=True, shape_size=5)
multi_study.print_f1star(tfit=tfit)
# Out:
# Evaluation_NoStop_L1-NoChip_2025-09-01_06:17, F1* = 0.57, P* = 0.46, R* = 0.75
# Evaluation_NoStop_L1-10_2025-08-26_04:53, F1* = 0.46, P* = 0.32, R* = 0.78
# Evaluation_NoStop_L1-20_2025-08-26_04:53, F1* = 0.67, P* = 0.57, R* = 0.80
# Evaluation_NoStop_L1-30_2025-08-29_12:53, F1* = 0.72, P* = 0.66, R* = 0.81
# Evaluation_NoStop_L1-R_2025-08-26_04:53, F1* = 0.68, P* = 0.58, R* = 0.81
#
# Evaluation_NoStop_L1-NoChip_2025-09-01_06:17&8&0.57&0.46&0.75\\
# Evaluation_NoStop_L1-10_2025-08-26_04:53&8&0.46&0.32&0.78\\
# Evaluation_NoStop_L1-20_2025-08-26_04:53&8&0.67&0.57&0.80\\
# Evaluation_NoStop_L1-30_2025-08-29_12:53&8&0.72&0.66&0.81\\
# Evaluation_NoStop_L1-R_2025-08-26_04:53&8&0.68&0.58&0.81\\

# %%
#No Stop experiments done at epoch 75 
A7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-NoChip_2025-09-01_06:17"
A3 = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-30_2025-08-29_12:53'
A4 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-30Small_2025-08-29_12:52"
A5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-R_2025-08-26_04:53"
A6 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-SmallR_2025-09-01_06:17"


color_legend=["No Chipping", "30% Overlap", "Random Overlap", "Data Limited 30% Overlap", "Data Limited Random Overlap"]
shape_legend=["Telescope A", "Telescope A",  "Telescope A","Telescope A","Telescope A"]
# shape_legend=["Baseline", "Overlap",  "Overlap","Data Limited","Data Limited"]
experiments = [ A7, A3, A5, A4, A6]

tfit=8

save_path = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/SPIEFutureSensingImageChipping/NoStopping/WithSmall'
multi_study = Multi_Dataset_Study(experiments, color_legend, second_characteristic=shape_legend,save_path=save_path, second_char_type="shape", color_gradient=None)
multi_study.plot_combined_PR_Curves(threshold_fit=tfit, split_legend=True, shape_size=5)
multi_study.print_f1star(tfit=tfit)
# Out:
# Evaluation_NoStop_L1-NoChip_2025-09-01_06:17, F1* = 0.57, P* = 0.46, R* = 0.75
# Evaluation_NoStop_L1-30_2025-08-29_12:53, F1* = 0.72, P* = 0.66, R* = 0.81
# Evaluation_NoStop_L1-R_2025-08-26_04:53, F1* = 0.68, P* = 0.58, R* = 0.81
# Evaluation_NoStop_L1-30Small_2025-08-29_12:52, F1* = 0.45, P* = 0.32, R* = 0.74
# Evaluation_NoStop_L1-SmallR_2025-09-01_06:17, F1* = 0.41, P* = 0.29, R* = 0.73
#
# Evaluation_NoStop_L1-NoChip_2025-09-01_06:17&8&0.57&0.46&0.75\\
# Evaluation_NoStop_L1-30_2025-08-29_12:53&8&0.72&0.66&0.81\\
# Evaluation_NoStop_L1-R_2025-08-26_04:53&8&0.68&0.58&0.81\\
# Evaluation_NoStop_L1-30Small_2025-08-29_12:52&8&0.45&0.32&0.74\\
# Evaluation_NoStop_L1-SmallR_2025-09-01_06:17&8&0.41&0.29&0.73\\

# %%
#No Stop experiments done at epoch 75 
A7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-NoChip_2025-09-01_06:17"
A8 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=0.33_2025-09-11_06:10"
A9 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=24_2025-09-11_06:10"
A10 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=2_2025-09-15_04:58"
A11 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=5_2025-09-12_04:50"


color_legend=["No Chipping", "R=0.33", "R=1", "R=2", "R=5"]
shape_legend=["Telescope A", "Telescope A",  "Telescope A","Telescope A","Telescope A"]
experiments = [ A7, A8, A9, A10, A11]

tfit=8

save_path = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/SPIEFutureSensingImageChipping/NoStopping/variedR'
multi_study = Multi_Dataset_Study(experiments, color_legend, second_characteristic=shape_legend,save_path=save_path, second_char_type="shape", color_gradient=None)
multi_study.plot_combined_PR_Curves(threshold_fit=tfit, split_legend=True, shape_size=5)
multi_study.print_f1star(tfit=tfit)
# Out:
# Evaluation_NoStop_L1-NoChip_2025-09-01_06:17, F1* = 0.57, P* = 0.46, R* = 0.75
# Eval_L1-R=0.33_2025-09-11_06:10, F1* = 0.52, P* = 0.39, R* = 0.79
# Eval_L1-R=24_2025-09-11_06:10, F1* = 0.69, P* = 0.61, R* = 0.80
# Eval_L1-R=2_2025-09-15_04:58, F1* = 0.70, P* = 0.60, R* = 0.82
# Eval_L1-R=5_2025-09-12_04:50, F1* = 0.77, P* = 0.72, R* = 0.84
#
# Evaluation_NoStop_L1-NoChip_2025-09-01_06:17&8&0.57&0.46&0.75\\
# Eval_L1-R=0.33_2025-09-11_06:10&8&0.52&0.39&0.79\\
# Eval_L1-R=24_2025-09-11_06:10&8&0.69&0.61&0.80\\
# Eval_L1-R=2_2025-09-15_04:58&8&0.70&0.60&0.82\\
# Eval_L1-R=5_2025-09-12_04:50&8&0.77&0.72&0.84\\

# %%
#No Stop experiments done at epoch 75 
A1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-NoChip_2025-09-01_06:17" #6737
A2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-10_2025-08-26_04:53" #10058
A3 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-20_2025-08-26_04:53" #10322
A4 = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-30_2025-08-29_12:53' #26863
A5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-R_2025-08-26_04:53" #15369
A6 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-30Small_2025-08-29_12:52" #10000
A7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-SmallR_2025-09-01_06:17" #10000
A8 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=0.33_2025-09-11_06:10" #9018
A9 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=24_2025-09-11_06:10" #13669
A10 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=2_2025-09-15_04:58" #20936
A11 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R=5_2025-09-12_04:50" #42690
A12 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-alpha=0.125_2025-09-12_04:52"



color_legend=["R=0.5", "R=0.33", "R=1", "R=2", "R=5"]
shape_legend=["Telescope A", "Telescope A",  "Telescope A","Telescope A","Telescope A"]
experiments = [A2,A8,A9,A10,A11]
dataset_sizes = [10058,9018,13669,20936,42690]
# color_legend=["R=0.5", "R=0.33", "R=1", "R=2"]
# shape_legend=["Telescope A", "Telescope A",  "Telescope A","Telescope A"]
# experiments = [A2,A8,A9,A10]
# dataset_sizes = [10058,9018,13669,20936]

tfit=8

save_path = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/SPIEFutureSensingImageChipping/NoStopping/variedR'
multi_study = Multi_Dataset_Study(experiments, color_legend, second_characteristic=shape_legend,save_path=save_path, second_char_type="shape", color_gradient=None, dataset_sizes=dataset_sizes)
multi_study.plot_combined_PR_Curves(threshold_fit=tfit, split_legend=True, shape_size=5)
multi_study.print_f1star(tfit=tfit)
multi_study.calculate_scaling_law(tfit=8, tconf=0.1, shape_color="#0699F4", fit_color="#F0A104")
# Out:
# Evaluation_NoStop_L1-10_2025-08-26_04:53, F1* = 0.46, P* = 0.32, R* = 0.78
# Eval_L1-R=0.33_2025-09-11_06:10, F1* = 0.52, P* = 0.39, R* = 0.79
# Eval_L1-R=24_2025-09-11_06:10, F1* = 0.69, P* = 0.61, R* = 0.80
# Eval_L1-R=2_2025-09-15_04:58, F1* = 0.70, P* = 0.60, R* = 0.82
# Eval_L1-R=5_2025-09-12_04:50, F1* = 0.77, P* = 0.72, R* = 0.84
#
# Evaluation_NoStop_L1-10_2025-08-26_04:53&8&0.46&0.32&0.78\\
# Eval_L1-R=0.33_2025-09-11_06:10&8&0.52&0.39&0.79\\
# Eval_L1-R=24_2025-09-11_06:10&8&0.69&0.61&0.80\\
# Eval_L1-R=2_2025-09-15_04:58&8&0.70&0.60&0.82\\
# Eval_L1-R=5_2025-09-12_04:50&8&0.77&0.72&0.84\\
# Precision Scaling Law: M_inf=0.7492663241808479, alpha=1.4508036473086439
# Recall Scaling Law: M_inf=0.8869922028125479, alpha=0.5024753416590854
# F1 Scaling Law: M_inf=0.7969769187342849, alpha=1.5827520531951802

# %%
#No Stop experiments done at epoch 75 
A1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-10_2025-08-26_04:53"
A2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-20_2025-08-26_04:53"
A3 = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-30_2025-08-29_12:53'
A4 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-30Small_2025-08-29_12:52"
A5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-R_2025-08-26_04:53"
A6 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-SmallR_2025-09-01_06:17"
A7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Evaluation_NoStop_L1-NoChip_2025-09-01_06:17"
B1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-10_on_L2_2025-09-05_06:35"
B2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-20_on_L2_2025-09-05_06:35"
B3 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-30Large_on_L2_2025-09-05_07:46"
B4 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-30_on_L2_2025-09-05_06:36"
B5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-RLarge_on_L2_2025-09-05_07:46"
B6 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R_on_L2_2025-09-05_06:36"
B7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-NoChip_on_L2_2025-09-05_08:13"
C1 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-10_on_R4_2025-09-05_06:37"
C2 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-20_on_R4_2025-09-05_06:37"
C3 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-30Large_on_R4_2025-09-05_07:49"
C4 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-30_on_R4_2025-09-05_06:38"
C5 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-RLarge_on_R4_2025-09-05_07:49"
C6 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-R_on_R4_2025-09-05_06:38"
C7 = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Experiments/Eval_L1-NoChip_on_R4_2025-09-05_08:19"

color_legend=["10% Overlap", "20% Overlap","30% Overlap","30% Small Overlap", "R Overlap", "R Small Overlap", "No Chip", "10% Overlap", "20% Overlap","30% Overlap","30% Small Overlap", "R Overlap", "R Small Overlap", "No Chip", "10% Overlap", "20% Overlap","30% Overlap","30% Small Overlap", "R Overlap", "R Small Overlap", "No Chip"]
shape_legend=["Telescope A", "Telescope A",  "Telescope A","Telescope A","Telescope A", "Telescope A","Telescope A","Telescope B","Telescope B","Telescope B","Telescope B","Telescope B","Telescope B","Telescope B", "Telescope C", "Telescope C","Telescope C", "Telescope C","Telescope C", "Telescope C", "Telescope C"]

experiments = [A1,A2,A3,A4,A5,A6,A7,B1,B2,B3,B4,B5,B6,B7,C1,C2,C3,C4,C5,C6,C7]

save_path = '/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Plots/SPIEFutureSensingImageChipping/No_stop_Cross_Sensor'
multi_study = Multi_Dataset_Study(experiments, color_legend, second_characteristic=shape_legend,save_path=save_path, second_char_type="shape", color_gradient=None)
multi_study.plot_combined_PR_Curves(threshold_fit=4, split_legend=True, shape_size=4.5)
